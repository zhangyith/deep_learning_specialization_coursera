# %%
# save the environment dependencies

#!conda list --explicit > ../coursera-deeplearning-ai-course4-condaenv.txt
#!conda list --explicit > ../coursera-deeplearning-ai-course2-week2-condaenv.txt

# package all notebook content by week

# !tar chzvf ./coursera-deeplearning-ai-course5.tgz ./* --exclude ./coursera-deeplearning-ai-course5.tgz

#!tar chzvf ../coursera-deeplearning-ai-course4-week1.tgz ../week1/* --exclude ../coursera-deeplearning-ai-course4-week1.tgz

#!tar chzvf ../coursera-deeplearning-ai-course4-week2.tgz ../week2/* --exclude ../coursera-deeplearning-ai-course4-week2.tgz

#!tar chzvf ../coursera-deeplearning-ai-course4-week3.tgz ../week3/* --exclude ../coursera-deeplearning-ai-course4-week3.tgz

#!tar chzvf ../coursera-deeplearning-ai-course4-week4.tgz ../week4/* --exclude ../coursera-deeplearning-ai-course4-week4.tgz

# !split -b 100M ./coursera-deeplearning-ai-course5.tgz "coursera-deeplearning-ai-course5.part"

#!split -b 200M ../coursera-deeplearning-ai-course4-week1.tgz "coursera-deeplearning-ai-course4-week1.part"

#!split -b 200M ../coursera-deeplearning-ai-course4-week2.tgz "coursera-deeplearning-ai-course4-week2.part"

#!split -b 200M ../coursera-deeplearning-ai-course4-week3.tgz "coursera-deeplearning-ai-course4-week3.part"

#!split -b 200M ../coursera-deeplearning-ai-course4-week4.tgzIt"coursera-deeplearning-ai-course4-week4.part"
# Out:
# ./Week 1/
# ./Week 1/Building a Recurrent Neural Network - Step by Step/
# ./Week 1/Building a Recurrent Neural Network - Step by Step/Building a Recurrent Neural Network - Step by Step - v3.ipynb
# ./Week 1/Building a Recurrent Neural Network - Step by Step/utils.py
# ./Week 1/Building a Recurrent Neural Network - Step by Step/shakespeare.txt
# ./Week 1/Building a Recurrent Neural Network - Step by Step/data/
# ./Week 1/Building a Recurrent Neural Network - Step by Step/data/input.txt
# ./Week 1/Building a Recurrent Neural Network - Step by Step/.ipynb_checkpoints/
# ./Week 1/Building a Recurrent Neural Network - Step by Step/.ipynb_checkpoints/Building a Recurrent Neural Network - Step by Step - v3-checkpoint.ipynb
# ./Week 1/Building a Recurrent Neural Network - Step by Step/previous versions/
# ./Week 1/Building a Recurrent Neural Network - Step by Step/previous versions/.ipynb_checkpoints/
# ./Week 1/Building a Recurrent Neural Network - Step by Step/previous versions/.ipynb_checkpoints/Building a Recurrent Neural Network - Step by Step - v2-checkpoint.ipynb
# ./Week 1/Building a Recurrent Neural Network - Step by Step/previous versions/.ipynb_checkpoints/Building a Recurrent Neural Network - Step by Step - v1-checkpoint.ipynb
# ./Week 1/Building a Recurrent Neural Network - Step by Step/previous versions/Building a Recurrent Neural Network - Step by Step - v1.ipynb
# ./Week 1/Building a Recurrent Neural Network - Step by Step/previous versions/Building a Recurrent Neural Network - Step by Step - v2.ipynb
# ./Week 1/Building a Recurrent Neural Network - Step by Step/images/
# ./Week 1/Building a Recurrent Neural Network - Step by Step/images/rnn_step_forward.png
# ./Week 1/Building a Recurrent Neural Network - Step by Step/images/LSTM_rnn.png
# ./Week 1/Building a Recurrent Neural Network - Step by Step/images/RNN.png
# ./Week 1/Building a Recurrent Neural Network - Step by Step/images/rnn.png
# ./Week 1/Building a Recurrent Neural Network - Step by Step/images/rnn_cell_backprop.png
# ./Week 1/Building a Recurrent Neural Network - Step by Step/images/initial_state.png
# ./Week 1/Building a Recurrent Neural Network - Step by Step/images/LSTM.png
# ./Week 1/Building a Recurrent Neural Network - Step by Step/__pycache__/
# ./Week 1/Building a Recurrent Neural Network - Step by Step/__pycache__/utils.cpython-36.pyc
# ./Week 1/Building a Recurrent Neural Network - Step by Step/__pycache__/rnn_utils.cpython-36.pyc
# ./Week 1/Building a Recurrent Neural Network - Step by Step/rnn_utils.py
# ./Week 1/Dinosaur Island -- Character-level language model/
# ./Week 1/Dinosaur Island -- Character-level language model/utils.py
# ./Week 1/Dinosaur Island -- Character-level language model/models/
# ./Week 1/Dinosaur Island -- Character-level language model/models/model_shakespeare_kiank.h5
# ./Week 1/Dinosaur Island -- Character-level language model/models/model_shakespeare_kiank_350_epoch.h5
# ./Week 1/Dinosaur Island -- Character-level language model/Dinosaurus Island -- Character level language model final - v3.ipynb
# ./Week 1/Dinosaur Island -- Character-level language model/shakespeare.txt
# ./Week 1/Dinosaur Island -- Character-level language model/.ipynb_checkpoints/
# ./Week 1/Dinosaur Island -- Character-level language model/.ipynb_checkpoints/Dinosaurus Island -- Character level language model final - v3-checkpoint.ipynb
# ./Week 1/Dinosaur Island -- Character-level language model/previous versions/
# ./Week 1/Dinosaur Island -- Character-level language model/previous versions/Dinosaurus Island -- Character level language model final - v2-Copy1.ipynb
# ./Week 1/Dinosaur Island -- Character-level language model/previous versions/Dinosaurus Island -- Character level language model final - v1.ipynb
# ./Week 1/Dinosaur Island -- Character-level language model/previous versions/Dinosaurus Island -- Character-level language model - (final) - learners.ipynb
# ./Week 1/Dinosaur Island -- Character-level language model/previous versions/.ipynb_checkpoints/
# ./Week 1/Dinosaur Island -- Character-level language model/previous versions/.ipynb_checkpoints/Dinosaurus Island -- Character level language model final - v2-Copy1-checkpoint.ipynb
# ./Week 1/Dinosaur Island -- Character-level language model/previous versions/.ipynb_checkpoints/Dinosaurus Island -- Character-level language model - (final) - learners-checkpoint.ipynb
# ./Week 1/Dinosaur Island -- Character-level language model/previous versions/.ipynb_checkpoints/Dinosaurus Island -- Character level language model final - v1-checkpoint.ipynb
# ./Week 1/Dinosaur Island -- Character-level language model/images/
# ./Week 1/Dinosaur Island -- Character-level language model/images/rnn.png
# ./Week 1/Dinosaur Island -- Character-level language model/images/mangosaurus.jpeg
# ./Week 1/Dinosaur Island -- Character-level language model/images/dino.jpg
# ./Week 1/Dinosaur Island -- Character-level language model/images/dinos3.png
# ./Week 1/Dinosaur Island -- Character-level language model/images/shakespeare.jpg
# ./Week 1/Dinosaur Island -- Character-level language model/images/clip.png
# ./Week 1/Dinosaur Island -- Character-level language model/__pycache__/
# ./Week 1/Dinosaur Island -- Character-level language model/__pycache__/utils.cpython-36.pyc
# ./Week 1/Dinosaur Island -- Character-level language model/__pycache__/shakespeare_utils.cpython-36.pyc
# ./Week 1/Dinosaur Island -- Character-level language model/shakespeare_utils.py
# ./Week 1/Dinosaur Island -- Character-level language model/dinos.txt
# ./Week 1/Jazz improvisation with LSTM/
# ./Week 1/Jazz improvisation with LSTM/inference_code.py
# ./Week 1/Jazz improvisation with LSTM/music_utils.py
# ./Week 1/Jazz improvisation with LSTM/midi.py
# ./Week 1/Jazz improvisation with LSTM/data/
# ./Week 1/Jazz improvisation with LSTM/data/30s_seq.mp3
# ./Week 1/Jazz improvisation with LSTM/data/30s_trained_model.mp3
# ./Week 1/Jazz improvisation with LSTM/data/original_metheny.mid
# ./Week 1/Jazz improvisation with LSTM/data/deepjazz_on_metheny...128_epochs.midi
# ./Week 1/Jazz improvisation with LSTM/data/training_example.mp3
# ./Week 1/Jazz improvisation with LSTM/.ipynb_checkpoints/
# ./Week 1/Jazz improvisation with LSTM/.ipynb_checkpoints/Improvise a Jazz Solo with an LSTM Network - v3-checkpoint.ipynb
# ./Week 1/Jazz improvisation with LSTM/Improvise a Jazz Solo with an LSTM Network - v3.ipynb
# ./Week 1/Jazz improvisation with LSTM/previous versions/
# ./Week 1/Jazz improvisation with LSTM/previous versions/Improvise a Jazz Solo with an LSTM Network - v1.ipynb
# ./Week 1/Jazz improvisation with LSTM/previous versions/.ipynb_checkpoints/
# ./Week 1/Jazz improvisation with LSTM/previous versions/.ipynb_checkpoints/Improvise a Jazz Solo with an LSTM Network - v2-checkpoint.ipynb
# ./Week 1/Jazz improvisation with LSTM/previous versions/.ipynb_checkpoints/Improvise a Jazz Solo with an LSTM Network - v1-checkpoint.ipynb
# ./Week 1/Jazz improvisation with LSTM/previous versions/Improvise a Jazz Solo with an LSTM Network - v2.ipynb
# ./Week 1/Jazz improvisation with LSTM/images/
# ./Week 1/Jazz improvisation with LSTM/images/model.png
# ./Week 1/Jazz improvisation with LSTM/images/jazz.jpg
# ./Week 1/Jazz improvisation with LSTM/images/music_gen.png
# ./Week 1/Jazz improvisation with LSTM/images/music_generation.png
# ./Week 1/Jazz improvisation with LSTM/grammar.py
# ./Week 1/Jazz improvisation with LSTM/tune1.midi
# ./Week 1/Jazz improvisation with LSTM/data_utils.py
# ./Week 1/Jazz improvisation with LSTM/output/
# ./Week 1/Jazz improvisation with LSTM/output/my_music.midi
# ./Week 1/Jazz improvisation with LSTM/qa.py
# ./Week 1/Jazz improvisation with LSTM/__pycache__/
# ./Week 1/Jazz improvisation with LSTM/__pycache__/music_utils.cpython-36.pyc
# ./Week 1/Jazz improvisation with LSTM/__pycache__/grammar.cpython-36.pyc
# ./Week 1/Jazz improvisation with LSTM/__pycache__/midi.cpython-36.pyc
# ./Week 1/Jazz improvisation with LSTM/__pycache__/preprocess.cpython-36.pyc
# ./Week 1/Jazz improvisation with LSTM/__pycache__/qa.cpython-36.pyc
# ./Week 1/Jazz improvisation with LSTM/__pycache__/data_utils.cpython-36.pyc
# ./Week 1/Jazz improvisation with LSTM/__pycache__/lstm.cpython-36.pyc
# ./Week 1/Jazz improvisation with LSTM/preprocess.py
# ./Week 2/
# ./Week 2/Word Vector Representation/
# ./Week 2/Word Vector Representation/Operations on word vectors - v2.ipynb
# ./Week 2/Word Vector Representation/data/
# ./Week 2/Word Vector Representation/data/glove.6B.50d.txt
